# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("source/diabetes2.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## 1.1 Histogram
# - In this section represent all the graph how the columns values have.

# %%
p = df.hist(figsize = (15,15))

# %% [markdown]
# ## 1.2 null value count analysis
# ###  In this section represent mainly three terms
# - Total rows number
# - Total columns number
# - Missing Values each columns
# ####  In this dataset have no missing value

# %%
import missingno as msno
msno.bar(df, figsize = (15,8))
plt.show()

# %% [markdown]
# ## 1.3 Target Values Analysis with Histogram
# - In this section represent target values details
# - How many types of target value
# - How many values in each types

# %%
print(df.groupby('Outcome').size())
print(df["Outcome"].value_counts())
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
ax = sns.countplot(x='Outcome',data=df)

# %% [markdown]
# ## 1.4 Lineplot Age vs Pregnancies
# - Draw a line plot with possibility of several semantic groupings.
# - X axis represent Age
# - Y axis represent Pregnancies
# - Each point represent a mean value of pregnancies by age

# %%
plt.figure(figsize=(15,8))
ax = sns.lineplot(x='Age',y='Pregnancies',data=df)
plt.show()

# %%
df[453:460]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 453            2      119              0              0        0  19.6
# 454            2      100             54             28      105  37.8
# 455           14      175             62             30        0  33.6
# 456            1      135             54              0        0  26.7
# 457            5       86             68             28       71  30.2
# 458           10      148             84             48      237  37.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 453                     0.832   72        0
# 454                     0.498   24        0
# 455                     0.212   38        1
# 456                     0.687   62        0
# 457                     0.364   24        0
# 458                     1.001   51        1
# 459                     0.460   81        0

# %% [markdown]
# ## 1.5 Lineplot Age vs BloodPressure
#
# - Draw a line plot with possibility of several semantic groupings.
# - X axis represent Age
# - Y axis represent BloodPressure
# - Each point represent a mean value of BloodPressure by age

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='Age',y='BloodPressure',data=df)
plt.show()

# %%
dd = df.Age>70
dd.value_counts()
# Out:
# False    766
# True       2
# Name: Age, dtype: int64

# %% [markdown]
# ## 1.6 Lineplot Age vs Glucose
#
# - Draw a line plot with possibility of several semantic groupings.
# - X axis represent Age
# - Y axis represent Glucose
# - Each point represent a mean value of glucose by age

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='Age',y='Glucose',data=df)
plt.show()

# %% [markdown]
# ## 1.7 Lineplot Age vs Outcome
#
# - Draw a line plot with possibility of several semantic groupings.
# - X axis represent Age
# - Y axis represent Outcome
# - Each point represent a mean value of Outcome by age

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='Age',y='Outcome',data=df)
plt.show()

# %% [markdown]
# ## 1.8 Distplot All Data
#
# - Flexibly plot a univariate distribution of observations.

# %%
fig, ax = plt.subplots(4,2, figsize=(16,16))
sns.distplot(df.Age, bins = 20, ax=ax[0,0]) 
sns.distplot(df.Pregnancies, bins = 20, ax=ax[0,1]) 
sns.distplot(df.Glucose, bins = 20, ax=ax[1,0]) 
sns.distplot(df.BloodPressure, bins = 20, ax=ax[1,1]) 
sns.distplot(df.SkinThickness, bins = 20, ax=ax[2,0])
sns.distplot(df.Insulin, bins = 20, ax=ax[2,1])
sns.distplot(df.DiabetesPedigreeFunction, bins = 20, ax=ax[3,0]) 
sns.distplot(df.BMI, bins = 20, ax=ax[3,1])
plt.show()

# %% [markdown]
# ## 1.9 Pair Plots All Data
#
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our dataset.

# %%
plt.figure(figsize=(15,15))
sns.pairplot(data=df,hue='Outcome')
plt.show()
#height=2,aspect=1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ## 1.10 Violin Plots All data
#
# A violin plot is a method of plotting numeric data. It is similar to box plot with a rotated kernel density plot on each side. Violin plots are similar to box plots, except that they also show the probability density of the data at different values (in the simplest case this could be a histogram).
#
# A violin plot is more informative than a plain box plot. In fact while a box plot only shows summary statistics such as mean/median and interquartile ranges, the violin plot shows the full distribution of the data. The difference is particularly useful when the data distribution is multimodal (more than one peak). In this case a violin plot clearly shows the presence of different peaks, their position and relative amplitude. This information could not be represented with a simple box plot which only reports summary statistics. The inner part of a violin plot usually shows the mean (or median) and the interquartile range.

# %%
fig,ax = plt.subplots(nrows=4, ncols=2, figsize=(15,15))
plt.suptitle('Violin Plots',fontsize=24)
sns.violinplot(x="Pregnancies", data=df,ax=ax[0,0],palette='Set3')
sns.violinplot(x="Glucose", data=df,ax=ax[0,1],palette='Set3')
sns.violinplot (x ='BloodPressure', data=df, ax=ax[1,0], palette='Set3')
sns.violinplot(x='SkinThickness', data=df, ax=ax[1,1],palette='Set3')
sns.violinplot(x='Insulin', data=df, ax=ax[2,0], palette='Set3')
sns.violinplot(x='BMI', data=df, ax=ax[2,1],palette='Set3')
sns.violinplot(x='DiabetesPedigreeFunction', data=df, ax=ax[3,0],palette='Set3')
sns.violinplot(x='Age', data=df, ax=ax[3,1],palette='Set3')
plt.show()

# %% [markdown]
# ## 1.11 Countplot for Pregnancies
#
# - Show the counts of observations in each categorical bin using bars.

# %%
plt.figure(figsize=(15,15))
sns.countplot(df["Pregnancies"])
plt.show()

# %% [markdown]
# ## 1.12 Correlation between features
#
# Variables within a dataset can be related for lots of reasons. It can be useful in data analysis and modeling to better understand the relationships between variables. The statistical relationship between two variables is referred to as their correlation.
#
# A correlation could be positive, meaning both variables move in the same direction, or negative, meaning that when one variable’s value increases, the other variables’ values decrease. Correlation can also be neural or zero, meaning that the variables are unrelated.

# %%
corr=df.corr()

plt.figure(figsize=(14,8))

sns.heatmap(corr, vmax=.8, linewidths=0.01,annot=True,cmap='summer',linecolor="black")
plt.title('Correlation between features')
plt.show()

# %%
#df.Age.unique()

# %%
#d = df.Pregnancies.unique()
#print(d)

# %% [markdown]
# ## Model Predict

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
mod = LogisticRegression()

x=df.iloc[:,0:8]
y = df.iloc[:,8]
x11,x22,y11,y22 = train_test_split(x,y, test_size=.2)


mod.fit(x11,y11)

score = round(mod.score(x22,y22)*100,2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
x1 = float(input("Enter Your Pregnancies number: "))
x2 = float(input("Enter Your Glucose number: "))
x3 = float(input("Enter Your BloodPresure number: "))
x4 = float(input("Enter Your SkinThickness number: "))
x5 = float(input("Enter Your Insulin number: "))
x6 = float(input("Enter Your BMI number: "))
x7 = float(input("Enter Your DiabetesPedigreeFunction number: "))
x8 = float(input("Enter Your Age: "))

x9 = [x1,x2,x3,x4,x5,x6,x7,x8]

predict = mod.predict([x9])

print(" ")

if predict == 1:
    print("You Are Diabetes Affected & This Possibilities is",score,"%")
else:
    print("You Are Not Diabetes Affected & This Possibilities is",score,"%")
# Out:
# Enter Your Pregnancies number: 5
# Enter Your Glucose number: 88
# Enter Your BloodPresure number: 105
# Enter Your SkinThickness number: 44
# Enter Your Insulin number: 22
# Enter Your BMI number: 44
# Enter Your DiabetesPedigreeFunction number: .665
# Enter Your Age: 40
#
# You Are Not Diabetes Affected & This Possibilities is 77.92 %

# %% [markdown]
# ## 1.14 Model Confusion Matrix

# %%
y_pr = mod.predict(x22)
from sklearn.metrics import confusion_matrix
cmm = confusion_matrix(y22,y_pr)
cmm
# Out:
# array([[83,  8],
#        [26, 37]], dtype=int64)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cmm, annot=True)
plt.show()
